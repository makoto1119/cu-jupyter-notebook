# %%
import sys
sys.dont_write_bytecode = True

# for debug print
def chkprint(*args):
    from inspect import currentframe
    names = {id(v):k for k,v in currentframe().f_back.f_locals.items()}
    print(', '.join(names.get(id(arg),'???')+' : '+str(type(arg))+' = '+repr(arg) for arg in args))

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import all_estimators
import warnings

# %%
# アヤメデータの読み込み
iris_data = pd.read_csv("iris.csv", encoding="utf-8")

# アヤメデータをラベルと入力データに分離する 
y = iris_data.loc[:,"Name"]
x = iris_data.loc[:,["SepalLength","SepalWidth","PetalLength","PetalWidth"]]

# 学習用とテスト用に分離する 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, train_size = 0.8, shuffle = True)

# classifierのアルゴリズム全てを取得する --- (※1)
allAlgorithms = all_estimators(type_filter="classifier")
warnings.simplefilter("error")

for(name, algorithm) in allAlgorithms :
  try :
    print("\n name       : " + name)
    #print("algorithm: " + str(algorithm))
    chkprint(algorithm)
    
    # 各アリゴリズムのオブジェクトを作成 --- (※2)  
    if(name == "LinearSVC") :
      clf = algorithm(max_iter = 10000)
    else:
      clf = algorithm()

    # 学習して、評価する --- (※3)
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print(name,"の正解率 = " , accuracy_score(y_test, y_pred))
  
  # WarningやExceptionの内容を表示する --- (※4)
  except Warning as w :
    print("\033[33m"+"Warning："+"\033[0m", name, ":", w.args)
  except Exception as e :
    print("\033[31m"+"Error："+"\033[0m", name, ":", e.args)
# Out:
#  name       : AdaBoostClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# Warning： AdaBoostClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : BaggingClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._bagging.BaggingClassifier'>
# Warning： BaggingClassifier : ('`np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : BernoulliNB
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.naive_bayes.BernoulliNB'>
# BernoulliNB の正解率 =  0.26666666666666666
#
#  name       : CalibratedClassifierCV
# algorithm : <class 'type'> = <class 'sklearn.calibration.CalibratedClassifierCV'>
# Warning： CalibratedClassifierCV : ('Liblinear failed to converge, increase the number of iterations.',)
#
#  name       : CategoricalNB
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.naive_bayes.CategoricalNB'>
# CategoricalNB の正解率 =  0.9666666666666667
#
#  name       : ClassifierChain
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.multioutput.ClassifierChain'>
# Error： ClassifierChain : ("__init__() missing 1 required positional argument: 'base_estimator'",)
#
#  name       : ComplementNB
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.naive_bayes.ComplementNB'>
# ComplementNB の正解率 =  0.7
#
#  name       : DecisionTreeClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# Warning： DecisionTreeClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : DummyClassifier
# algorithm : <class 'type'> = <class 'sklearn.dummy.DummyClassifier'>
# Warning： DummyClassifier : ('The default value of strategy will change from stratified to prior in 0.24.',)
#
#  name       : ExtraTreeClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.tree._classes.ExtraTreeClassifier'>
# Warning： ExtraTreeClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : ExtraTreesClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._forest.ExtraTreesClassifier'>
# Warning： ExtraTreesClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : GaussianNB
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.naive_bayes.GaussianNB'>
# GaussianNB の正解率 =  0.9
#
#  name       : GaussianProcessClassifier
# algorithm : <class 'type'> = <class 'sklearn.gaussian_process._gpc.GaussianProcessClassifier'>
# GaussianProcessClassifier の正解率 =  0.9666666666666667
#
#  name       : GradientBoostingClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._gb.GradientBoostingClassifier'>
# Warning： GradientBoostingClassifier : ('`np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe. \nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : HistGradientBoostingClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'>
# HistGradientBoostingClassifier の正解率 =  0.8666666666666667
#
#  name       : KNeighborsClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# Warning： KNeighborsClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : LabelPropagation
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.semi_supervised._label_propagation.LabelPropagation'>
# Warning： LabelPropagation : ('`np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : LabelSpreading
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.semi_supervised._label_propagation.LabelSpreading'>
# Warning： LabelSpreading : ('`np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : LinearDiscriminantAnalysis
# algorithm : <class 'type'> = <class 'sklearn.discriminant_analysis.LinearDiscriminantAnalysis'>
# LinearDiscriminantAnalysis の正解率 =  0.9333333333333333
#
#  name       : LinearSVC
# algorithm : <class 'type'> = <class 'sklearn.svm._classes.LinearSVC'>
# LinearSVC の正解率 =  0.8
#
#  name       : LogisticRegression
# algorithm : <class 'type'> = <class 'sklearn.linear_model._logistic.LogisticRegression'>
# Warning： LogisticRegression : ('tostring() is deprecated. Use tobytes() instead.',)
#
#  name       : LogisticRegressionCV
# algorithm : <class 'type'> = <class 'sklearn.linear_model._logistic.LogisticRegressionCV'>
# Warning： LogisticRegressionCV : ('tostring() is deprecated. Use tobytes() instead.',)
#
#  name       : MLPClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.neural_network._multilayer_perceptron.MLPClassifier'>
# Warning： MLPClassifier : ("Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.",)
#
#  name       : MultiOutputClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.multioutput.MultiOutputClassifier'>
# Error： MultiOutputClassifier : ("__init__() missing 1 required positional argument: 'estimator'",)
#
#  name       : MultinomialNB
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.naive_bayes.MultinomialNB'>
# MultinomialNB の正解率 =  0.8666666666666667
#
#  name       : NearestCentroid
# algorithm : <class 'type'> = <class 'sklearn.neighbors._nearest_centroid.NearestCentroid'>
# Warning： NearestCentroid : ('`np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : NuSVC
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.svm._classes.NuSVC'>
# NuSVC の正解率 =  0.9666666666666667
#
#  name       : OneVsOneClassifier
# algorithm : <class 'type'> = <class 'sklearn.multiclass.OneVsOneClassifier'>
# Error： OneVsOneClassifier : ("__init__() missing 1 required positional argument: 'estimator'",)
#
#  name       : OneVsRestClassifier
# algorithm : <class 'type'> = <class 'sklearn.multiclass.OneVsRestClassifier'>
# Error： OneVsRestClassifier : ("__init__() missing 1 required positional argument: 'estimator'",)
#
#  name       : OutputCodeClassifier
# algorithm : <class 'type'> = <class 'sklearn.multiclass.OutputCodeClassifier'>
# Error： OutputCodeClassifier : ("__init__() missing 1 required positional argument: 'estimator'",)
#
#  name       : PassiveAggressiveClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveClassifier'>
# PassiveAggressiveClassifier の正解率 =  0.7666666666666667
#
#  name       : Perceptron
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.linear_model._perceptron.Perceptron'>
# Perceptron の正解率 =  0.7
#
#  name       : QuadraticDiscriminantAnalysis
# algorithm : <class 'type'> = <class 'sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis'>
# QuadraticDiscriminantAnalysis の正解率 =  0.9333333333333333
#
#  name       : RadiusNeighborsClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.neighbors._classification.RadiusNeighborsClassifier'>
# Warning： RadiusNeighborsClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : RandomForestClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# Warning： RandomForestClassifier : ('`np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.\nDeprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations',)
#
#  name       : RidgeClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.linear_model._ridge.RidgeClassifier'>
# RidgeClassifier の正解率 =  0.8
#
#  name       : RidgeClassifierCV
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.linear_model._ridge.RidgeClassifierCV'>
# RidgeClassifierCV の正解率 =  0.8
#
#  name       : SGDClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.linear_model._stochastic_gradient.SGDClassifier'>
# SGDClassifier の正解率 =  0.8666666666666667
#
#  name       : SVC
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.svm._classes.SVC'>
# SVC の正解率 =  0.9666666666666667
#
#  name       : StackingClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._stacking.StackingClassifier'>
# Error： StackingClassifier : ("__init__() missing 1 required positional argument: 'estimators'",)
#
#  name       : VotingClassifier
# algorithm : <class 'abc.ABCMeta'> = <class 'sklearn.ensemble._voting.VotingClassifier'>
# Error： VotingClassifier : ("__init__() missing 1 required positional argument: 'estimators'",)
